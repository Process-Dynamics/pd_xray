# %%
from pd_xray.data.formats.tiff import TIFFReader

# %%
path = "/home/bozkurt/emre/tomography/ma2574_ID19/4/tiff_data/ma2574_0040005_pag_db0100_0500.tif"

# %%
tiff_reader = TIFFReader()

# %%
slice_sample = tiff_reader.read_single_file(path)

# %%
import matplotlib.pyplot as plt

plt.imshow(slice_sample, cmap="gray")
plt.show()
