# %%
from pd_xray.data.formats.edf import EDFReader

# %%
path = "/home/bozkurt/emre/tomography/ma2574_ID19/42/ma2574_0420000.edf"

# %%
edf_reader = EDFReader()

start = 0
end = 500

# %%
data = edf_reader.read(path, start_frame=start, end_frame=end)
print(data.shape)
# Out:
# (500, 1008, 1008)

# %%
data_header = edf_reader.read_header(path)
print(data_header)
# Out:
# {'HeaderID': 'EH:000001:000000:000000', 'Image': '1', 'ByteOrder': 'LowByteFirst', 'DataType': 'UnsignedShort', 'Dim_1': '1008', 'Dim_2': '1008', 'Size': '2032128', 'count_time': '0.0009284', 'point_no': '0', 'preset': '0.9284', 'col_end': '1512', 'col_beg': '505', 'row_end': '1512', 'row_beg': '505', 'dir': 'Y:\\\\ma2574\\\\id19\\\\unioxf\\ma2574_042\\', 'suffix': '.edf', 'prefix': 'ma2574_042', 'run': '1', 'title': 'CCD Image', 'shape': (1008, 1008), 'dtype': 'uint16'}

# %%
single_edf = "/home/bozkurt/emre/tomography/ma2574_ID19/42/refHST_ma2574_042_0000_0000.edf"
single_data = edf_reader.read_single_file(single_edf)
print(single_data.shape)
# Out:
# (1008, 1008)
