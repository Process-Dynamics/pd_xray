# %%
from pd_xray.data.backends.local import LocalBackend

# %%
path = "/home/bozkurt/emre/tomography/ma2574_ID19/42"

# %%
with LocalBackend(root=path) as backend:
    backend.connect()
    files = backend.list_files(pattern="*.edf", recursive=True)
    print(files)
# Out:
# [FileInfo(path='ma2574_0420000.edf', size_bytes=45745920000, is_directory=False), FileInfo(path='ma2574_042_avgdarkfile_0000.edf', size_bytes=2032640, is_directory=False), FileInfo(path='refHST_ma2574_042_0000_0000.edf', size_bytes=2032640, is_directory=False)]
